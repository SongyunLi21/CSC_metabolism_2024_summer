# %% [markdown]
# # Compass Analysis

# %% [markdown]
# This notebook gives a small demo of analyzing the results of the compass algorithm and replicates figures 2E and 2C from the paper.

# %% [markdown]
# To install the required python packages, you can uncomment the "install_reqs()" call.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from compass_analysis import cohens_d, wilcoxon_test, get_reaction_consistencies, get_metareactions, labeled_reactions, amino_acid_metab

# %%
from matplotlib import __version__ as matplotlibversion
if matplotlibversion < "3.4":
    print("Matplotlib versions older than 3.4 may not be able to generate figure 2E, as they do not support alpha arrays")

# %% [markdown]
# The file "extdata/Th17/reactions.tsv" is the outputs of a compass run and "extdata/Th17/cell_metadata.csv" is cell metadata, in this case it is only used to know the condition of the Th17 cells (pathogenic vs. non-pathogenic). Commented out are alternative files to use for a microcpooled example.

# %%
foldername = "BC_GSE176078"
dataname = "CID4066"
#cell_metadata  = pd.read_csv("data/{foldername}/{dataname}_cluster_metadata.csv".format(foldername=foldername,dataname=dataname), index_col=0)
reaction_penalties = pd.read_csv("data/{foldername}/{dataname}_reactions.tsv".format(foldername=foldername,dataname=dataname), sep="\t", index_col=0)

# %%
reaction_penalties
# Out:
#                          CID4066_AGTAGTCGTAAGTGGC  CID4066_CCATGTCAGTCCCACG  \
# 10FTHF5GLUtl_pos                      4688.892765               4603.915384
# 10FTHF5GLUtm_pos                      6354.219676               6372.867896
# 10FTHF6GLUtl_pos                      5996.055118               5855.204012
# 10FTHF6GLUtm_pos                      6823.892699               6839.224882
# 10FTHF7GLUtl_pos                      6760.021419               6480.871193
# ...                                           ...                       ...
# sink_pre_prot(r)_pos                     0.000000                  0.000000
# sink_tetdec2coa(c)_neg               22951.735506              22985.147776
# sink_tetdec2coa(c)_pos                   0.000000                  0.000000
# sink_tetdece1coa(c)_neg              22951.735506              22985.147776
# sink_tetdece1coa(c)_pos                  0.000000                  0.000000
#
#                          CID4066_CCGGGATTCTGCAGTA  CID4066_CGGGTCATCGAATGCT  \
# 10FTHF5GLUtl_pos                      4484.036459               4163.078595
# 10FTHF5GLUtm_pos                      5825.526981               5462.378771
# 10FTHF6GLUtl_pos                      5574.243312               5111.051507
# 10FTHF6GLUtm_pos                      6276.059122               5842.227283
# 10FTHF7GLUtl_pos                      6134.137914               5592.934915
# ...                                           ...                       ...
# sink_pre_prot(r)_pos                     0.000000                  0.000000
# sink_tetdec2coa(c)_neg               22240.886358              19679.775899
# sink_tetdec2coa(c)_pos                   0.000000                  0.000000
# sink_tetdece1coa(c)_neg              22240.886358              19679.775899
# sink_tetdece1coa(c)_pos                  0.000000                  0.000000
#
#                          CID4066_GAAGCAGCACTGAAGG  CID4066_GCCTCTACAAGCGCTC  \
# 10FTHF5GLUtl_pos                      4398.241211               4689.555630
# 10FTHF5GLUtm_pos                      5649.598070               6446.065877
# 10FTHF6GLUtl_pos                      5525.648847               5993.737379
# 10FTHF6GLUtm_pos                      6090.236919               6940.477510
# 10FTHF7GLUtl_pos                      6103.689047               6765.501468
# ...                                           ...                       ...
# sink_pre_prot(r)_pos                     0.000000                  0.000000
# sink_tetdec2coa(c)_neg               21690.637397              23440.020172
# sink_tetdec2coa(c)_pos                   0.000000                  0.000000
# sink_tetdece1coa(c)_neg              21690.637397              23440.020172
# sink_tetdece1coa(c)_pos                  0.000000                  0.000000
#
#                          CID4066_ACGAGCCAGAGACTTA  CID4066_GGCTCGACAGGCAGTA  \
# 10FTHF5GLUtl_pos                      4142.081364               4160.476078
# 10FTHF5GLUtm_pos                      5606.684950               5647.085992
# 10FTHF6GLUtl_pos                      5111.471263               5140.816457
# 10FTHF6GLUtm_pos                      5973.008025               6031.982413
# 10FTHF7GLUtl_pos                      5602.188106               5715.466335
# ...                                           ...                       ...
# sink_pre_prot(r)_pos                     0.000000                  0.000000
# sink_tetdec2coa(c)_neg               21445.278600              19361.617444
# sink_tetdec2coa(c)_pos                   0.000000                  0.000000
# sink_tetdece1coa(c)_neg              21445.278600              19361.617444
# sink_tetdece1coa(c)_pos                  0.000000                  0.000000
#
#                          CID4066_GTGGGTCGTCTTTCAT  CID4066_TACTTACTCCAGAGGA  \
# 10FTHF5GLUtl_pos                      4610.089716               4628.205622
# 10FTHF5GLUtm_pos                      6432.120070               6387.520784
# 10FTHF6GLUtl_pos                      5863.779795               5893.081652
# 10FTHF6GLUtm_pos                      6922.653990               6856.029712
# 10FTHF7GLUtl_pos                      6505.302943               6551.426057
# ...                                           ...                       ...
# sink_pre_prot(r)_pos                     0.000000                  0.000000
# sink_tetdec2coa(c)_neg               22561.411546              23126.192057
# sink_tetdec2coa(c)_pos                   0.000000                  0.000000
# sink_tetdece1coa(c)_neg              22561.411546              23126.192057
# sink_tetdece1coa(c)_pos                  0.000000                  0.000000
#
#                          ...  CID4066_TTCTTAGTCAAGGTAA  \
# 10FTHF5GLUtl_pos         ...               4579.596128
# 10FTHF5GLUtm_pos         ...               6355.507231
# 10FTHF6GLUtl_pos         ...               5819.901281
# 10FTHF6GLUtm_pos         ...               6820.026245
# 10FTHF7GLUtl_pos         ...               6646.818903
# ...                      ...                       ...
# sink_pre_prot(r)_pos     ...                  0.000000
# sink_tetdec2coa(c)_neg   ...              23263.766493
# sink_tetdec2coa(c)_pos   ...                  0.000000
# sink_tetdece1coa(c)_neg  ...              23263.766493
# sink_tetdece1coa(c)_pos  ...                  0.000000
#
#                          CID4066_TTGAACGGTAGTACCT  CID4066_TTGAACGTCCAGAAGG  \
# 10FTHF5GLUtl_pos                      4031.819826               4651.397987
# 10FTHF5GLUtm_pos                      5513.629604               6478.945203
# 10FTHF6GLUtl_pos                      4937.799983               5930.653355
# 10FTHF6GLUtm_pos                      5826.804009               6983.950902
# 10FTHF7GLUtl_pos                      5409.462581               6635.078460
# ...                                           ...                       ...
# sink_pre_prot(r)_pos                     0.000000                  0.000000
# sink_tetdec2coa(c)_neg               19046.426752              23284.574543
# sink_tetdec2coa(c)_pos                   0.000000                  0.000000
# sink_tetdece1coa(c)_neg              19046.426752              23284.574543
# sink_tetdece1coa(c)_pos                  0.000000                  0.000000
#
#                          CID4066_TTGACTTAGTCTCGGC  CID4066_TTGACTTTCACCACCT  \
# 10FTHF5GLUtl_pos                      4021.299542               4107.423633
# 10FTHF5GLUtm_pos                      5469.141997               5563.055144
# 10FTHF6GLUtl_pos                      4918.971830               5058.526517
# 10FTHF6GLUtm_pos                      5752.519035               5889.137791
# 10FTHF7GLUtl_pos                      5370.988282               5610.582550
# ...                                           ...                       ...
# sink_pre_prot(r)_pos                     0.000000                  0.000000
# sink_tetdec2coa(c)_neg               19667.220223              19695.241413
# sink_tetdec2coa(c)_pos                   0.000000                  0.000000
# sink_tetdece1coa(c)_neg              19667.220223              19695.241413
# sink_tetdece1coa(c)_pos                  0.000000                  0.000000
#
#                          CID4066_TTGACTTTCCTTTCGG  CID4066_TTGCCGTCATGGTTGT  \
# 10FTHF5GLUtl_pos                      4245.015700               4478.183774
# 10FTHF5GLUtm_pos                      5656.377015               6019.803828
# 10FTHF6GLUtl_pos                      5221.664446               5594.563853
# 10FTHF6GLUtm_pos                      6079.287703               6543.571785
# 10FTHF7GLUtl_pos                      5713.473996               6165.041909
# ...                                           ...                       ...
# sink_pre_prot(r)_pos                     0.000000                  0.000000
# sink_tetdec2coa(c)_neg               20469.859414              22397.186734
# sink_tetdec2coa(c)_pos                   0.000000                  0.000000
# sink_tetdece1coa(c)_neg              20469.859414              22397.186734
# sink_tetdece1coa(c)_pos                  0.000000                  0.000000
#
#                          CID4066_TTGTAGGAGAAACCGC  CID4066_TTTATGCTCGGCCGAT  \
# 10FTHF5GLUtl_pos                      3814.132438               3979.619939
# 10FTHF5GLUtm_pos                      5174.384478               6010.350080
# 10FTHF6GLUtl_pos                      4586.451370               4852.367316
# 10FTHF6GLUtm_pos                      5379.618701               6331.857376
# 10FTHF7GLUtl_pos                      4986.113344               5434.198900
# ...                                           ...                       ...
# sink_pre_prot(r)_pos                     0.000000                  0.000000
# sink_tetdec2coa(c)_neg               19069.009580              19326.578114
# sink_tetdec2coa(c)_pos                   0.000000                  0.000000
# sink_tetdece1coa(c)_neg              19069.009580              19326.578114
# sink_tetdece1coa(c)_pos                  0.000000                  0.000000
#
#                          CID4066_TTTATGCTCTCGTTTA
# 10FTHF5GLUtl_pos                      4322.822783
# 10FTHF5GLUtm_pos                      6044.770258
# 10FTHF6GLUtl_pos                      5371.552139
# 10FTHF6GLUtm_pos                      6343.885939
# 10FTHF7GLUtl_pos                      5855.801357
# ...                                           ...
# sink_pre_prot(r)_pos                     0.000000
# sink_tetdec2coa(c)_neg               22249.208124
# sink_tetdec2coa(c)_pos                   0.000000
# sink_tetdece1coa(c)_neg              22249.208124
# sink_tetdece1coa(c)_pos                  0.000000
#
# [10211 rows x 521 columns]

# %%
cell_metadata = pd.read_csv("data/{foldername}/{dataname}_cell_meta.csv".format(foldername=foldername,dataname=dataname),index_col = 0)
#cell_metadata = pd.read_csv("extdata/Th17-micropooled/cluster_metadata.csv", index_col = 0)

# %%
cell_metadata
# Out:
#                                   celltype
# CID4066_AGTAGTCGTAAGTGGC             other
# CID4066_CCATGTCAGTCCCACG             other
# CID4066_CCGGGATTCTGCAGTA             other
# CID4066_CGGGTCATCGAATGCT  cancer stem cell
# CID4066_GAAGCAGCACTGAAGG             other
# ...                                    ...
# CID4066_TTGACTTTCCTTTCGG  cancer stem cell
# CID4066_TTGCCGTCATGGTTGT             other
# CID4066_TTGTAGGAGAAACCGC             other
# CID4066_TTTATGCTCGGCCGAT  cancer stem cell
# CID4066_TTTATGCTCTCGTTTA             other
#
# [521 rows x 1 columns]

# %%
# pathogenic Th17 = Th17p; non-pathogenic Th17 = Th17n
Th17p_cells = cell_metadata.index[cell_metadata['celltype'] == 'cancer stem cell']
Th17n_cells = cell_metadata.index[cell_metadata['celltype'] == 'other']

# %%
Th17p_cells
# Out:
# Index(['CID4066_CGGGTCATCGAATGCT', 'CID4066_AAGGTTCAGGTGTGGT',
#        'CID4066_ACATGGTAGGTGTGGT', 'CID4066_ACGAGGAAGGGAAACA',
#        'CID4066_ACGATGTCATATGCTG', 'CID4066_ACTATCTGTGTGACCC',
#        'CID4066_ACTGAGTAGCGCTCCA', 'CID4066_ATTATCCAGTCCCACG',
#        'CID4066_CATCAAGGTAGCGTAG', 'CID4066_CCGGTAGCATGCAATC',
#        ...
#        'CID4066_TGGCCAGGTACGAAAT', 'CID4066_TGGGCGTTCATAGCAC',
#        'CID4066_TGGTTAGCAATGGACG', 'CID4066_TGGTTAGGTAATTGGA',
#        'CID4066_TGTCCCACATGCTAGT', 'CID4066_TTCTTAGCAATGTAAG',
#        'CID4066_TTGACTTAGTCTCGGC', 'CID4066_TTGACTTTCACCACCT',
#        'CID4066_TTGACTTTCCTTTCGG', 'CID4066_TTTATGCTCGGCCGAT'],
#       dtype='object', length=182)

# %% [markdown]
# The reaction metadata for RECON2 is stored here. We'll be using the confidence scores and the subsystem groupings to filter out reactions and group them for analysis.

# %%
reaction_metadata = pd.read_csv("extdata/RECON2/reaction_metadata.csv", index_col = 0)

# %%
reaction_metadata
# Out:
#                                                     reaction_name  \
# reaction_no_direction
# 10FTHF5GLUtl               5-glutamyl-10FTHF transport, lysosomal
# 10FTHF5GLUtm           5-glutamyl-10FTHF transport, mitochondrial
# 10FTHF6GLUtl               6-glutamyl-10FTHF transport, lysosomal
# 10FTHF6GLUtm           6-glutamyl-10FTHF transport, mitochondrial
# 10FTHF7GLUtl               7-glutamyl-10FTHF transport, lysosomal
# ...                                                           ...
# MAL_Lte                                     Transport of L-malate
# OROTGLUt                                                 OROTGLUt
# PNTOte                              Transport of (R)-Pantothenate
# IDOURte                      L-iduronate transport, extracellular
# EX_idour(e)                               Exchange of L-iduronate
#
#                                                                  formula  \
# reaction_no_direction
# 10FTHF5GLUtl           1.00 * 10-formyltetrahydrofolate-[Glu](5) [c] ...
# 10FTHF5GLUtm           1.00 * 10-formyltetrahydrofolate-[Glu](5) [m] ...
# 10FTHF6GLUtl           1.00 * 10-formyltetrahydrofolate-[Glu](6) [c] ...
# 10FTHF6GLUtm           1.00 * 10-formyltetrahydrofolate-[Glu](6) [m] ...
# 10FTHF7GLUtl           1.00 * 10-formyltetrahydrofolate-[Glu](7) [c] ...
# ...                                                                  ...
# MAL_Lte                1.00 * (S)-malate(2-) [e] --> 1.00 * (S)-malat...
# OROTGLUt               1.00 * L-glutamate(1-) [c] + 1.00 * Orotate [e...
# PNTOte                 1.00 * (R)-Pantothenate [e] --> 1.00 * (R)-Pan...
# IDOURte                1.00 * L-iduronate [e] --> 1.00 * L-iduronate ...
# EX_idour(e)                     1.00 * L-iduronate [e] --> ϕ\r\nNo genes
#
#                       associated_genes                 subsystem EC_number  \
# reaction_no_direction
# 10FTHF5GLUtl                       NaN      Transport, lysosomal       NaN
# 10FTHF5GLUtm                       NaN  Transport, mitochondrial       NaN
# 10FTHF6GLUtl                       NaN      Transport, lysosomal       NaN
# 10FTHF6GLUtm                       NaN  Transport, mitochondrial       NaN
# 10FTHF7GLUtl                       NaN      Transport, lysosomal       NaN
# ...                                ...                       ...       ...
# MAL_Lte                            NaN  Transport, extracellular       NaN
# OROTGLUt                       SLC22A7  Transport, extracellular       NaN
# PNTOte                             NaN  Transport, extracellular       NaN
# IDOURte                            NaN  Transport, extracellular       NaN
# EX_idour(e)                        NaN  Exchange/demand reaction       NaN
#
#                        confidence
# reaction_no_direction
# 10FTHF5GLUtl                  2.0
# 10FTHF5GLUtm                  2.0
# 10FTHF6GLUtl                  2.0
# 10FTHF6GLUtm                  2.0
# 10FTHF7GLUtl                  2.0
# ...                           ...
# MAL_Lte                       NaN
# OROTGLUt                      NaN
# PNTOte                        NaN
# IDOURte                       NaN
# EX_idour(e)                   NaN
#
# [7440 rows x 6 columns]

# %% [markdown]
# Here is one example of a row for the reaction metadata:

# %% [markdown]
# The numbers in the reactions tsv correspond to penalties for each reaction per cell, so we take the negative log to get scores that are higher the more active the reaction is predicted to be. This also drops reactions that are close to constant and therefore not informative for the comparison.

# %%
#This function is repeated here for clarity
def get_reaction_consistencies(compass_reaction_penalties, min_range=1e-3):
    """
        Converts the raw penalties outputs of compass into scores per reactions where higher numbers indicate more activity
    """
    df = -np.log(compass_reaction_penalties + 1)
    df = df[df.max(axis=1) - df.min(axis=1) >= min_range]
    df = df - df.min().min()
    return df

# %%
df = -np.log(reaction_penalties + 1)

# %%
min_range=1e-3
df = df[df.max(axis=1) - df.min(axis=1) >= min_range]

# %%
reaction_consistencies = get_reaction_consistencies(reaction_penalties)

# %%
reaction_consistencies
# Out:
#                          CID4066_AGTAGTCGTAAGTGGC  CID4066_CCATGTCAGTCCCACG  \
# 10FTHF5GLUtl_pos                         3.545168                  3.563453
# 10FTHF5GLUtm_pos                         3.241301                  3.238371
# 10FTHF6GLUtl_pos                         3.299309                  3.323076
# 10FTHF6GLUtm_pos                         3.170001                  3.167757
# 10FTHF7GLUtl_pos                         3.179404                  3.221568
# ...                                           ...                       ...
# sink_decdicoa(c)_neg                     1.957140                  1.955686
# sink_octdececoa(c)_neg                   1.621055                  1.625063
# sink_pre_prot(r)_neg                     7.461492                  7.447649
# sink_tetdec2coa(c)_neg                   1.957140                  1.955686
# sink_tetdece1coa(c)_neg                  1.957140                  1.955686
#
#                          CID4066_CCGGGATTCTGCAGTA  CID4066_CGGGTCATCGAATGCT  \
# 10FTHF5GLUtl_pos                         3.589831                  3.664082
# 10FTHF5GLUtm_pos                         3.328156                  3.392510
# 10FTHF6GLUtl_pos                         3.372242                  3.458977
# 10FTHF6GLUtm_pos                         3.253676                  3.325294
# 10FTHF7GLUtl_pos                         3.276545                  3.368895
# ...                                           ...                       ...
# sink_decdicoa(c)_neg                     1.988600                  2.110935
# sink_octdececoa(c)_neg                   1.645662                  1.759816
# sink_pre_prot(r)_neg                     7.469269                  7.587275
# sink_tetdec2coa(c)_neg                   1.988600                  2.110935
# sink_tetdece1coa(c)_neg                  1.988600                  2.110935
#
#                          CID4066_GAAGCAGCACTGAAGG  CID4066_GCCTCTACAAGCGCTC  \
# 10FTHF5GLUtl_pos                         3.609145                  3.545026
# 10FTHF5GLUtm_pos                         3.358816                  3.226952
# 10FTHF6GLUtl_pos                         3.380996                  3.299696
# 10FTHF6GLUtm_pos                         3.283726                  3.153063
# 10FTHF7GLUtl_pos                         3.281520                  3.178593
# ...                                           ...                       ...
# sink_decdicoa(c)_neg                     2.013651                  1.936090
# sink_octdececoa(c)_neg                   1.684637                  1.592975
# sink_pre_prot(r)_neg                     7.516857                  7.450802
# sink_tetdec2coa(c)_neg                   2.013651                  1.936090
# sink_tetdece1coa(c)_neg                  2.013651                  1.936090
#
#                          CID4066_ACGAGCCAGAGACTTA  CID4066_GGCTCGACAGGCAGTA  \
# 10FTHF5GLUtl_pos                         3.669138                  3.664708
# 10FTHF5GLUtm_pos                         3.366440                  3.359261
# 10FTHF6GLUtl_pos                         3.458895                  3.453171
# 10FTHF6GLUtm_pos                         3.303159                  3.293336
# 10FTHF7GLUtl_pos                         3.367242                  3.347227
# ...                                           ...                       ...
# sink_decdicoa(c)_neg                     2.025026                  2.127233
# sink_octdececoa(c)_neg                   1.672247                  1.786270
# sink_pre_prot(r)_neg                     7.490786                  7.607544
# sink_tetdec2coa(c)_neg                   2.025026                  2.127233
# sink_tetdece1coa(c)_neg                  2.025026                  2.127233
#
#                          CID4066_GTGGGTCGTCTTTCAT  CID4066_TACTTACTCCAGAGGA  \
# 10FTHF5GLUtl_pos                         3.562113                  3.558192
# 10FTHF5GLUtm_pos                         3.229118                  3.236075
# 10FTHF6GLUtl_pos                         3.321613                  3.316629
# 10FTHF6GLUtm_pos                         3.155634                  3.165303
# 10FTHF7GLUtl_pos                         3.217806                  3.210742
# ...                                           ...                       ...
# sink_decdicoa(c)_neg                     1.974292                  1.949568
# sink_octdececoa(c)_neg                   1.622567                  1.604320
# sink_pre_prot(r)_neg                     7.461198                  7.450297
# sink_tetdec2coa(c)_neg                   1.974292                  1.949568
# sink_tetdece1coa(c)_neg                  1.974292                  1.949568
#
#                          ...  CID4066_TTCTTAGTCAAGGTAA  \
# 10FTHF5GLUtl_pos         ...                  3.568748
# 10FTHF5GLUtm_pos         ...                  3.241098
# 10FTHF6GLUtl_pos         ...                  3.329122
# 10FTHF6GLUtm_pos         ...                  3.170568
# 10FTHF7GLUtl_pos         ...                  3.196289
# ...                      ...                       ...
# sink_decdicoa(c)_neg     ...                  1.943637
# sink_octdececoa(c)_neg   ...                  1.611998
# sink_pre_prot(r)_neg     ...                  7.475465
# sink_tetdec2coa(c)_neg   ...                  1.943637
# sink_tetdece1coa(c)_neg  ...                  1.943637
#
#                          CID4066_TTGAACGGTAGTACCT  CID4066_TTGAACGTCCAGAAGG  \
# 10FTHF5GLUtl_pos                         3.696112                  3.553195
# 10FTHF5GLUtm_pos                         3.383173                  3.221865
# 10FTHF6GLUtl_pos                         3.493455                  3.310274
# 10FTHF6GLUtm_pos                         3.327937                  3.146820
# 10FTHF7GLUtl_pos                         3.402243                  3.198056
# ...                                           ...                       ...
# sink_decdicoa(c)_neg                     2.143645                  1.942743
# sink_octdececoa(c)_neg                   1.824192                  1.600089
# sink_pre_prot(r)_neg                     7.631283                  7.432033
# sink_tetdec2coa(c)_neg                   2.143645                  1.942743
# sink_tetdece1coa(c)_neg                  2.143645                  1.942743
#
#                          CID4066_TTGACTTAGTCTCGGC  CID4066_TTGACTTTCACCACCT  \
# 10FTHF5GLUtl_pos                         3.698724                  3.677538
# 10FTHF5GLUtm_pos                         3.391273                  3.374250
# 10FTHF6GLUtl_pos                         3.497275                  3.469305
# 10FTHF6GLUtm_pos                         3.340766                  3.317298
# 10FTHF7GLUtl_pos                         3.409379                  3.365745
# ...                                           ...                       ...
# sink_decdicoa(c)_neg                     2.111573                  2.110150
# sink_octdececoa(c)_neg                   1.759495                  1.781841
# sink_pre_prot(r)_neg                     7.611403                  7.575891
# sink_tetdec2coa(c)_neg                   2.111573                  2.110150
# sink_tetdece1coa(c)_neg                  2.111573                  2.110150
#
#                          CID4066_TTGACTTTCCTTTCGG  CID4066_TTGCCGTCATGGTTGT  \
# 10FTHF5GLUtl_pos                         3.644596                  3.591137
# 10FTHF5GLUtm_pos                         3.357617                  3.295357
# 10FTHF6GLUtl_pos                         3.437570                  3.368603
# 10FTHF6GLUtm_pos                         3.285525                  3.211942
# 10FTHF7GLUtl_pos                         3.347575                  3.271520
# ...                                           ...                       ...
# sink_decdicoa(c)_neg                     2.071575                  1.981597
# sink_octdececoa(c)_neg                   1.724696                  1.606400
# sink_pre_prot(r)_neg                     7.522412                  7.436542
# sink_tetdec2coa(c)_neg                   2.071575                  1.981597
# sink_tetdece1coa(c)_neg                  2.071575                  1.981597
#
#                          CID4066_TTGTAGGAGAAACCGC  CID4066_TTTATGCTCGGCCGAT  \
# 10FTHF5GLUtl_pos                         3.751602                  3.709140
# 10FTHF5GLUtm_pos                         3.446664                  3.296928
# 10FTHF6GLUtl_pos                         3.567253                  3.510905
# 10FTHF6GLUtm_pos                         3.407774                  3.244826
# 10FTHF7GLUtl_pos                         3.483720                  3.397681
# ...                                           ...                       ...
# sink_decdicoa(c)_neg                     2.142461                  2.129044
# sink_octdececoa(c)_neg                   1.792412                  1.790449
# sink_pre_prot(r)_neg                     7.619881                  7.654232
# sink_tetdec2coa(c)_neg                   2.142461                  2.129044
# sink_tetdece1coa(c)_neg                  2.142461                  2.129044
#
#                          CID4066_TTTATGCTCTCGTTTA
# 10FTHF5GLUtl_pos                         3.626438
# 10FTHF5GLUtm_pos                         3.291219
# 10FTHF6GLUtl_pos                         3.409274
# 10FTHF6GLUtm_pos                         3.242928
# 10FTHF7GLUtl_pos                         3.322974
# ...                                           ...
# sink_decdicoa(c)_neg                     1.988226
# sink_octdececoa(c)_neg                   1.650685
# sink_pre_prot(r)_neg                     7.473013
# sink_tetdec2coa(c)_neg                   1.988226
# sink_tetdece1coa(c)_neg                  1.988226
#
# [6379 rows x 521 columns]

# %% [markdown]
# We use the unpaired Wilcoxon rank-sum test (equivlanet to the Mann–Whitney U test) to analyze which reactions are predicted to be more active in pathogenic Th17p cells compared to the non-pathogenic Th17n cells. Positive values indicate higher potential activity in Th17p.

# %%
wilcox_results = wilcoxon_test(reaction_consistencies, Th17p_cells, Th17n_cells)
wilcox_results['metadata_r_id'] = ""
for r in wilcox_results.index:
    if r in reaction_metadata.index:
        wilcox_results.loc[r, 'metadata_r_id'] = r
    elif r[:-4] in reaction_metadata.index:
        wilcox_results.loc[r, 'metadata_r_id'] = r[:-4]
    else:
        print("Should not occur")

# %% [markdown]
# Next we join the metadata to the reactions in a new dataframe W, so that we can filter out non-core reactions. More specifically, we remove reactions with confidence other than 0 or 4 (4 = most confident; 0 = unassigned confidence) and filter out reactions in the citric acid cycle subsystem which are outside of the mitochondria.

# %%
W = wilcox_results.merge(reaction_metadata, how='left', 
                         left_on='metadata_r_id', right_index=True, validate='m:1')
W = W[W['confidence'].isin([0,4])]
W = W[~W['EC_number'].isna()]
W.loc[(W['formula'].map(lambda x: '[m]' not in x)) & (W['subsystem'] == "Citric acid cycle"), 'subsystem'] = 'Other'

# %% [markdown]
# Here is one example of a row of the reuslting dataframe for a reaction:

# %%
wilcox_results.loc[['r0281_pos']]
# Out:
#            wilcox_stat   wilcox_pval  cohens_d  adjusted_pval metadata_r_id
# r0281_pos      44232.0  3.115295e-16  0.792483   1.533369e-15         r0281

# %% [markdown]
# The "_neg" or "_pos" suffixes indicate one direction of a bidirectional reaction. The "_pos" direction indicates positive flux through the reaction. For this example reaction it indicates water, oxygen, and putrescine are being consumed by this reaction to produce ammonium, hyrodgen peroxide, and 4-Aminobutanal.

# %%
reaction_metadata.loc['r0281']['formula']
# Out:
# '1.00 * Water [e] + 1.00 * O2 [e] + 1.00 * Putrescine [e] --> 1.00 * Ammonium [e] + 1.00 * Hydrogen peroxide [e] + 1.00 * 4-Aminobutanal [e]\r\nAOC1'

# %%
W
# Out:
#                       wilcox_stat   wilcox_pval  cohens_d  adjusted_pval  \
# 2HBO_neg                  42723.0  4.239930e-13  0.709443   7.563343e-13
# 2HBO_pos                  42513.0  1.080659e-12  0.669331   1.797998e-12
# 34DHOXPEGOX_pos           43876.0  1.843072e-15  0.760524   6.718262e-15
# 34DHPLACOX_NADP__neg      42764.0  2.886000e-13  0.679965   5.316141e-13
# 34DHPLACOX_pos            42764.0  2.886000e-13  0.679965   5.316141e-13
# ...                           ...           ...       ...            ...
# r1467_neg                 40899.5  4.063059e-11  0.615161   5.759612e-11
# r1467_pos                 43362.0  2.210964e-14  0.764736   5.639241e-14
# r1487_pos                 42432.0  1.548842e-12  0.698875   2.517855e-12
# r1488_pos                 43073.0  8.566284e-14  0.716819   1.823301e-13
# r1492_pos                 45659.5  2.681136e-20  0.842441   2.217965e-18
#
#                          metadata_r_id  \
# 2HBO_neg                          2HBO
# 2HBO_pos                          2HBO
# 34DHOXPEGOX_pos            34DHOXPEGOX
# 34DHPLACOX_NADP__neg  34DHPLACOX_NADP_
# 34DHPLACOX_pos              34DHPLACOX
# ...                                ...
# r1467_neg                        r1467
# r1467_pos                        r1467
# r1487_pos                        r1487
# r1488_pos                        r1488
# r1492_pos                        r1492
#
#                                                           reaction_name  \
# 2HBO_neg                          2-Hydroxybutyrate:NAD+ oxidoreductase
# 2HBO_pos                          2-Hydroxybutyrate:NAD+ oxidoreductase
# 34DHOXPEGOX_pos       3,4-Dihydroxyphenylethyleneglycol:NAD+ oxidore...
# 34DHPLACOX_NADP__neg  3,4-Dihydroxyphenylacetaldehyde:NADP+ oxidored...
# 34DHPLACOX_pos        3,4-Dihydroxyphenylacetaldehyde:NAD+ oxidoredu...
# ...                                                                 ...
# r1467_neg                                 Postulated transport reaction
# r1467_pos                                 Postulated transport reaction
# r1487_pos                                                    EC:6.2.1.3
# r1488_pos                                                    EC:6.2.1.3
# r1492_pos                                            Utilized transport
#
#                                                                 formula  \
# 2HBO_neg              1.00 * 2-Hydroxybutyrate [c] + 1.00 * Nicotina...
# 2HBO_pos              1.00 * 2-Hydroxybutyrate [c] + 1.00 * Nicotina...
# 34DHOXPEGOX_pos       1.00 * proton [c] + 1.00 * Nicotinamide adenin...
# 34DHPLACOX_NADP__neg  1.00 * Water [c] + 1.00 * Nicotinamide adenine...
# 34DHPLACOX_pos        1.00 * Water [c] + 1.00 * Nicotinamide adenine...
# ...                                                                 ...
# r1467_neg             1.00 * Octadecenoyl-CoA (n-C18:1CoA) [c] --> 1...
# r1467_pos             1.00 * Octadecenoyl-CoA (n-C18:1CoA) [c] --> 1...
# r1487_pos             1.00 * ATP [r] + 1.00 * Coenzyme A [r] + 1.00 ...
# r1488_pos             1.00 * ATP [c] + 1.00 * Coenzyme A [c] + 1.00 ...
# r1492_pos             1.00 * potassium [c] --> 1.00 * potassium [e]\...
#
#                                                        associated_genes  \
# 2HBO_neg                               LDHA; LDHAL6B; LDHB; LDHC; UEVLD
# 2HBO_pos                               LDHA; LDHAL6B; LDHB; LDHC; UEVLD
# 34DHOXPEGOX_pos                   ADH1; ADH4; ADH5; ADH6A; ADH7; ADHFE1
# 34DHPLACOX_NADP__neg                          ALDH3A1; ALDH3B1; ALDH3B3
# 34DHPLACOX_pos                       ALDH1A3; ALDH3A1; ALDH3B1; ALDH3B3
# ...                                                                 ...
# r1467_neg                                                           NaN
# r1467_pos                                                           NaN
# r1487_pos             ACSBG2; ACSL1; ACSL3; ACSL4; ACSL5; ACSL6; SLC...
# r1488_pos                                                           NaN
# r1492_pos                                   ABCC8; ABCC9; KCNJ11; KCNJ8
#
#                                      subsystem EC_number  confidence
# 2HBO_neg                 Propanoate metabolism  1.1.1.27         4.0
# 2HBO_pos                 Propanoate metabolism  1.1.1.27         4.0
# 34DHOXPEGOX_pos            Tyrosine metabolism   1.1.1.1         4.0
# 34DHPLACOX_NADP__neg       Tyrosine metabolism   1.2.1.5         4.0
# 34DHPLACOX_pos             Tyrosine metabolism   1.2.1.5         4.0
# ...                                        ...       ...         ...
# r1467_neg             Transport, mitochondrial  2.3.1.86         0.0
# r1467_pos             Transport, mitochondrial  2.3.1.86         0.0
# r1487_pos                 Fatty acid oxidation   6.2.1.3         0.0
# r1488_pos                 Fatty acid oxidation   6.2.1.3         0.0
# r1492_pos             Transport, extracellular   6.2.1.3         0.0
#
# [1877 rows x 11 columns]

# %% [markdown]
# ### Optional: Metareaction analysis
# [Metareactions](#Metareactions) are used in the paper rather than single reaction analysis and the section at the bottom of this notebook performs the same analysis using reactions clustered into metareactions.

# %% [markdown]
# #### Set the reaction labels

# %%
import pandas as pd
# Load the CSV file
# Filter based on reaction name
name_filter = W['reaction_name'].str.contains('linoleic|linolenic|L-carnitine', case=False, na=False)

# Filter based on reaction formula
formula_filter = W['formula'].str.contains('lino', case=False, na=False)

# Combine both filters
filtered_df = W[name_filter | formula_filter]

# Create the dictionary
labeled_reactions = filtered_df.set_index(filtered_df.index)['reaction_name'].to_dict()

# Print the dictionary to check
print(labeled_reactions)
# Out:
# {'DESAT18_10_pos': 'fatty acyl-CoA desaturase (n-C18:2CoA -> n-C18:3CoA)', 'DESAT18_6_pos': 'fatty acyl-CoA desaturase (n-C18:1CoA -> n-C18:2CoA)', 'DESAT18_7_pos': 'fatty acyl-CoA desaturase (n-C18:1CoA -> n-C18:2CoA)', 'DESAT18_8_pos': 'fatty acyl-CoA desaturase (n-C18:1CoA -> n-C18:2CoA)', 'DESAT18_9_pos': 'fatty acyl-CoA desaturase (n-C18:2CoA -> n-C18:3CoA)', 'DESAT20_1_pos': 'fatty acyl-CoA desaturase (n-C20:3CoA -> n-C20:4CoA)', 'DLNLCGCPT1_pos': 'carnitine O-palmitoyltransferase', 'FACOAL1821_neg': 'fatty-acid--CoA ligase', 'FACOAL1821_pos': 'fatty-acid--CoA ligase', 'FACOAL1822_neg': 'fatty-acid--CoA ligase', 'FACOAL1822_pos': 'fatty-acid--CoA ligase', 'FACOAL1831_neg': 'fatty-acid--CoA ligase', 'FACOAL1831_pos': 'fatty-acid--CoA ligase', 'FACOAL1832_pos': 'fatty-acid--CoA ligase', 'FACOAL203_neg': 'fatty-acid--CoA ligase', 'FACOAL203_pos': 'fatty-acid--CoA ligase', 'FAEL183_pos': 'fatty-acyl-CoA elongation (n-C18:3CoA)', 'FAOXC182806m_pos': 'Beta oxidation of fatty acid', 'FAOXC18280m_pos': 'Beta oxidation of fatty acid', 'FAOXC183803m_pos': 'Beta oxidation of fatty acid', 'FAOXC183806m_pos': 'Beta oxidation of fatty acid', 'FAOXC183806x_pos': 'Beta oxidation of long chain fatty acid', 'FAOXC2031836m_pos': 'Beta oxidation of fatty acid', 'FAOXC2251836m_pos': 'Beta oxidation of fatty acid', 'FAOXC2251836x_pos': 'Beta oxidation of long chain fatty acid', 'LNELDCCPT1_pos': 'carnitine O-palmitoyltransferase', 'LNLCCPT1_pos': 'carnitine O-palmitoyltransferase', 'LNLNCACPT1_pos': 'carnitine O-palmitoyltransferase', 'LNLNCGCPT1_pos': 'carnitine O-palmitoyltransferase', 'LNLNCGCPT2_pos': 'carnitine transferase', 'PI345P3P_pos': 'phosphatidylinositol-3,4,5-trisphosphate 3-phosphatase', 'PI345P3Pn_pos': 'phosphatidylinositol-3,4,5-trisphosphate 3-phosphatase, nuclear', 'PI45P3K_pos': 'phosphatidylinositol 4,5-bisphosphate 3-kinase', 'PI45P5P_pos': 'phosphatidylinositol-4,5-bisphosphate 5-phosphatase', 'PI45PLC_pos': 'phosphatidylinositol 4,5-bisphosphate phospholipase C', 'PI4P5K_pos': 'phosphatidylinositol 4-phosphate 5-kinase', 'PI5P4K_pos': 'phosphatidylinositol-5-phosphate 4-kinase', 'PPBNGS_pos': 'porphobilinogen synthase', 'RE0512M_pos': 'RE0512', 'RE1447M_pos': 'RE1447', 'RE1447N_pos': 'RE1447', 'RE1516M_pos': 'RE1516', 'RE1523M_pos': 'RE1523', 'RE1531M_pos': 'RE1531', 'RE2972M_pos': 'RE2972', 'RE2986X_pos': 'RE2986', 'RE2987X_pos': 'RE2987', 'RE2988X_pos': 'RE2988', 'r0434_neg': 'Palmitoyl-CoA:L-carnitine O-palmitoyltransferase Fatty acid metabolism EC:2.3.1.21', 'r0434_pos': 'Palmitoyl-CoA:L-carnitine O-palmitoyltransferase Fatty acid metabolism EC:2.3.1.21', 'r0437_neg': 'Palmitoyl-CoA:L-carnitine O-palmitoyltransferase Fatty acid metabolism EC:2.3.1.21', 'r0437_pos': 'Palmitoyl-CoA:L-carnitine O-palmitoyltransferase Fatty acid metabolism EC:2.3.1.21', 'r0441_pos': 'Palmitoyl-CoA:L-carnitine O-palmitoyltransferase Fatty acid metabolism EC:2.3.1.21', 'r0443_pos': 'Palmitoyl-CoA:L-carnitine O-palmitoyltransferase Fatty acid metabolism EC:2.3.1.21', 'r0636_pos': 'Octanoyl-CoA:L-carnitine O-octanoyltransferase EC:2.3.1.137', 'r0637_pos': 'Octanoyl-CoA:L-carnitine O-octanoyltransferase EC:2.3.1.137', 'r1168_pos': 'EC:2.3.1.26', 'r1179_pos': 'EC:3.1.1.13', 'r1257_pos': 'EC:6.2.1.3', 'r1259_pos': 'EC:6.2.1.3', 'r1260_pos': 'EC:6.2.1.3', 'r1466_neg': 'EC:2.3.1.86'}

# %% [markdown]
# #### box plot for each reaction in FAO

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.backends.backend_pdf as pdf_backend
# Example DataFrames and Series
# reaction_matrix = pd.read_csv('reaction_matrix.csv', index_col=0) # Load your matrix file
# metadata = pd.read_csv('metadata.csv', index_col=0, squeeze=True) # Load your metadata file

# Extract the reactions from the matrix based on reaction_label
reaction_ids = list(labeled_reactions.keys())
subset_matrix = reaction_consistencies .loc[reaction_ids]
transposed_matrix = subset_matrix.T
transposed_matrix.reset_index(inplace=True)
transposed_matrix.rename(columns={'index': 'cell'}, inplace=True)
pdf_pages = pdf_backend.PdfPages("plot/{foldername}/{dataname}.pdf".format(foldername=foldername,dataname=dataname))
# Combine with metadata to create a long-form DataFrame for plotting
# Transpose subset_matrix to get cells as rows
melted_matrix = transposed_matrix.melt(id_vars='cell', value_vars=reaction_ids,
                                      var_name='reaction_id', value_name='value')

# Map reaction_ids to reaction_names
melted_matrix['reaction_name'] = melted_matrix['reaction_id'].map(labeled_reactions)

# Add metadata to melted_matrix
melted_matrix = melted_matrix.join(cell_metadata, on='cell')

# Plot the boxplots
plt.figure(figsize=(5, 5))
palette = {
    'cancer stem cell': 'pink',
    'other': 'lightgreen'
}
# Loop through each reaction and plot
for reaction in reaction_ids:
    plt.figure(figsize=(5, 5))
    sns.boxplot(data=melted_matrix[melted_matrix['reaction_id'] == reaction],
                x='celltype', y='value', palette=palette)
    plt.title(f'Boxplot of {labeled_reactions[reaction]}')
    plt.xlabel('Cell Type')
    plt.ylabel('Value')
    pdf_pages.savefig()
    plt.close()
pdf_pages.close()

# %% [markdown]
# ### Figure 2C replication

# %%
from adjustText import adjust_text

def plot_differential_scores(data, title, c):
    plt.figure(figsize=(10,10))
    axs = plt.gca()
    axs.scatter(data['cohens_d'], -np.log10(data['adjusted_pval']), c=c)
    axs.set_xlabel("Cohen's d", fontsize=16)
    axs.set_ylabel("-log10 (Wilcoxon-adjusted p)", fontsize=16)
    #Everything after this should be tweaked depending on your application
    axs.set_xlim(-2.2, 2.2)
    axs.axvline(0, dashes=(3,3), c='black')
    axs.axhline(1, dashes=(3,3), c='black')
    axs.set_title(title, fontdict={'fontsize':20})
    axs.annotate('', xy=(0.5, -0.08), xycoords='axes fraction', xytext=(0, -0.08), 
            arrowprops=dict(arrowstyle="<-", color='#348C73', linewidth=4))
    axs.annotate('cancer stem cells', xy=(0.75, -0.12), xycoords='axes fraction', fontsize=16)
    axs.annotate('', xy=(0.5, -0.08), xycoords='axes fraction', xytext=(1, -0.08), 
            arrowprops=dict(arrowstyle="<-", color='#E92E87', linewidth=4))
    axs.annotate('other cancer cells', xy=(0.25, -0.12), xycoords='axes fraction', fontsize=16)
    # Track already annotated labels
    annotated_labels = set()
    texts = []
    
    for r in data.index:
        if r in labeled_reactions:
            x = data.loc[r, 'cohens_d']
            y = -np.log10(data.loc[r, 'adjusted_pval'])
            
            # Only annotate if the label has not been annotated yet
            if labeled_reactions[r] not in annotated_labels:
                offset = (20, 0) if x >= 0 else (-100, -40)
                texts.append(axs.text(x, y, labeled_reactions[r], 
                                      fontsize=8, ha='right', va='bottom', 
                                      bbox=dict(boxstyle="round,pad=0.3", edgecolor='none', facecolor='none')))
                annotated_labels.add(labeled_reactions[r])
                
    # Adjust text positions to avoid overlap
    adjust_text(texts, 
                expand_text=(5, 5), 
                expand_points=(5, 5), 
                arrowprops=dict(arrowstyle='->', color='gray'))

    plt.show()

# %%
filtered_data = pd.concat([W[W['subsystem'] == "Glycolysis/gluconeogenesis"],
             W[W['subsystem'] == "Citric acid cycle"],
            W[W['subsystem'].isin(amino_acid_metab)],
           W[W['subsystem'] == "Fatty acid oxidation"]])

# %%
data = W[W['subsystem'] == "Fatty acid oxidation"]
plot_differential_scores(data, "Fatty Acid Oxidation", c="lightskyblue")
# Out:
# Looks like you are using a tranform that doesn't support FancyArrowPatch, using ax.annotate instead. The arrows might strike through texts. Increasing shrinkA in arrowprops might help.

# %%
data = W
plot_differential_scores(data, "All", c="pink")

# %% [markdown]
# #### Box plot of FAO score

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Example DataFrames and Series
# reaction_matrix = pd.read_csv('reaction_matrix.csv', index_col=0) # Load your matrix file
# metadata = pd.read_csv('metadata.csv', index_col=0, squeeze=True) # Load your metadata file

# Extract the reactions from the matrix based on reaction_label
reaction_ids = list(labeled_reactions.keys())
subset_matrix = reaction_consistencies .loc[reaction_ids]
transposed_matrix = subset_matrix.T
transposed_matrix.reset_index(inplace=True)
transposed_matrix.rename(columns={'index': 'cell'}, inplace=True)

transposed_matrix['sum'] = transposed_matrix[labeled_reactions.keys()].sum(axis=1)
transposed_matrix = transposed_matrix.join(cell_metadata, on='cell')
palette = {
    'cancer stem cell': 'pink',
    'other': 'lightskyblue'
}
plt.figure(figsize=(5, 5))
sns.boxplot(data=transposed_matrix, x='celltype', y='sum', palette=palette)
plt.title('Boxplot of Summed FAO Reaction Scores')
plt.xlabel('Cancer Cell Type')
plt.ylabel('Sum of Scores')
plt.show()

# %% [markdown]
# ### Figure 2E replication

# %%
data = W[~W['subsystem'].isin(["Miscellaneous", "Unassigned"])]
data = data[~data['subsystem'].map(lambda x: "Transport" in x or "Exchange" in x or x == "Other")]
items, counts = np.unique(data['subsystem'], return_counts=True)
items = [items[i] for i in range(len(items)) if counts[i] > 5] #filter(n() > 5) %>%
data = data[data['subsystem'].isin(items)]

# %%
plt.figure(figsize=(12,12))
axs = plt.gca()
#Sorts the reactions for plotting
d = data[data['adjusted_pval'] < 0.1].groupby('subsystem')['cohens_d'].median().abs()
axs.scatter(d[d.argsort], d[d.argsort].index, alpha=0)
color = data['cohens_d'].map(lambda x: 'r' if x >= 0 else 'b')
alpha = data['adjusted_pval'].map(lambda x: 1.0 if x < 0.1 else 0.25)
axs.scatter(data['cohens_d'], data['subsystem'], c=color, alpha=alpha)
axs.set_xlabel("Cohen's d")
# Out:
# Text(0.5, 0, "Cohen's d")

# %% [markdown]
# #### box plot of FAO score in each cluster

# %%
cell_metadata = pd.read_csv("data/{foldername}/{dataname}_cluster_meta.csv".format(foldername=foldername,dataname=dataname),index_col = 0)
#cell_metadata = pd.read_csv("extdata/Th17-micropooled/cluster_metadata.csv", index_col = 0)import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Example DataFrames and Series
# reaction_matrix = pd.read_csv('reaction_matrix.csv', index_col=0) # Load your matrix file
# metadata = pd.read_csv('metadata.csv', index_col=0, squeeze=True) # Load your metadata file

# Extract the reactions from the matrix based on reaction_label
reaction_ids = list(labeled_reactions.keys())
subset_matrix = reaction_consistencies .loc[reaction_ids]
transposed_matrix = subset_matrix.T
transposed_matrix.reset_index(inplace=True)
transposed_matrix.rename(columns={'index': 'cell'}, inplace=True)

transposed_matrix['sum'] = transposed_matrix[labeled_reactions.keys()].sum(axis=1)
transposed_matrix = transposed_matrix.join(cell_metadata, on='cell')
plt.figure(figsize=(5, 5))
sns.boxplot(data=transposed_matrix, x='seurat_clusters', y='sum')
plt.title('Boxplot of Summed FAO Reaction Scores')
plt.xlabel('Clusters')
plt.ylabel('Sum of Scores')
plt.show()

# %% [markdown]
# #### classifed cluster in to low/medium/high group based on their FAO medium value

# %%
transposed_matrix = subset_matrix.T
transposed_matrix.reset_index(inplace=True)
transposed_matrix.rename(columns={'index': 'cell'}, inplace=True)
    
# Melt the matrix for long-form DataFrame
melted_matrix = transposed_matrix.melt(id_vars='cell', value_vars=reaction_ids,
                                       var_name='reaction_id', value_name='value')
    
# Map reaction_ids to reaction_names
melted_matrix['reaction_name'] = melted_matrix['reaction_id'].map(labeled_reactions)
    
melted_matrix = melted_matrix.join(cell_metadata, on='cell')
    
# Process data for all reactions
transposed_matrix['sum'] = transposed_matrix[reaction_ids].sum(axis=1)
df = transposed_matrix.join(cell_metadata, on='cell')

# %%
def classify_value(value):
    if value <= 305:
        return 'low'
    elif 305 < value <= 310:
        return 'mid'
    else:
        return 'high'
results = []
celltype_column = "seurat_clusters"
sum_column = "sum"
for celltype in sorted(df[celltype_column].unique()):
    celltype_df = df[df[celltype_column] == celltype]
    # Calculate top 25% and top 75% thresholds
    top_50 = celltype_df[sum_column].quantile(0.5)
    print(classify_value(top_50))
    celltype_df['classification'] = classify_value(top_50)
    # Collect results
    results.append(celltype_df[['cell', 'classification']])
            
     # Combine results and save to a new file
    results_df = pd.concat(results, ignore_index=True)
    output_file_path = f"data/{foldername}/{dataname}_classified.csv"
    results_df.to_csv(output_file_path, index=False)
# Out:
# mid
# low
# mid
# low
# mid
# mid
# C:\Users\HUAWEI\AppData\Local\Temp\ipykernel_17944\2870572520.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   celltype_df['classification'] = classify_value(top_50)
# C:\Users\HUAWEI\AppData\Local\Temp\ipykernel_17944\2870572520.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   celltype_df['classification'] = classify_value(top_50)
# C:\Users\HUAWEI\AppData\Local\Temp\ipykernel_17944\2870572520.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   celltype_df['classification'] = classify_value(top_50)
# C:\Users\HUAWEI\AppData\Local\Temp\ipykernel_17944\2870572520.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   celltype_df['classification'] = classify_value(top_50)
# C:\Users\HUAWEI\AppData\Local\Temp\ipykernel_17944\2870572520.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   celltype_df['classification'] = classify_value(top_50)
# C:\Users\HUAWEI\AppData\Local\Temp\ipykernel_17944\2870572520.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   celltype_df['classification'] = classify_value(top_50)
